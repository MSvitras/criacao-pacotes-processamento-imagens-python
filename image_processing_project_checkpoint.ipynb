# %%
from image_processing_mila.utils import io, plot
from image_processing_mila.processing import combination, transformation

# %%
# read the images
image1 = io.read_image('c:/users/mila/python_image/images/oceano.jpg')
image2 = io.read_image('c:/users/mila/python_image/images/flores.jpg')

# %%
#display the imagens
plot.plot_image(image1)
plot.plot_image(image2)

# %%
#combination 
result_image = combination.transfer_histogram(image1, image2)
plot.plot_result(image1, image2, result_image)

# %%
import numpy as np
import skimage.color
import skimage.io
import matplotlib.pyplot as plt

# %%
# read the image 
image = skimage.io.imread(fname='c:/users/mila/python_image/images/oceano.jpg', as_gray=True)

#display the image
fig, ax = plt.subplots()
plt.imshow(image, cmap='gray')
plt.show()
